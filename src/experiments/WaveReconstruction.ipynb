# %%
import sys

sys.path.append('..')

import pickle
import numpy as np
import matplotlib.pyplot as plt

from VISTorchUtils import VISDataPoint
from utils import waveFromCochleagram
from IPython.display import Audio

# %%
with open('/scratch/vis_data/train/12002.pkl', 'rb') as f:
    dp: VISDataPoint = pickle.load(f)

# %%
coch = dp.cochleagram

# %%
plt.imshow(dp.frames[1])
plt.show()

# %%
dp.material
# Out:
# 'wood'

# %%
wave = waveFromCochleagram(coch)

# %%
plt.plot(range(len(wave)), wave)
plt.show()

# %%
Audio(wave, rate=96000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
